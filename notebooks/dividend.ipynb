# %% [raw]
# ---
# title: Dividend Analysis
# author: Justin Donaldson
# format:
#   html:
#     code-fold: true
# ---

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
#| label: fig-polar
#| fig-cap: A line plot on a polar axis

pd.DataFrame([1,2,3,4]).plot()
# Out:
# <Axes: >
